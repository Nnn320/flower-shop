# %%
# !pip install requests
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting requests
#   Downloading https://mirrors.aliyun.com/pypi/packages/7c/e4/56027c4a6b4ae70ca9de302488c5ca95ad4a39e190093d6c1a8ace08341b/requests-2.32.4-py3-none-any.whl (64 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading https://mirrors.aliyun.com/pypi/packages/05/35/bb59b1cd012d7196fc81c2f5879113971efc226a63812c9cf7f89fe97c40/charset_normalizer-3.4.3-cp38-cp38-win_amd64.whl (105 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading https://mirrors.aliyun.com/pypi/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl (70 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ce/d9/5f4c13cecde62396b0d3fe530a50ccea91e7dfc1ccf0e09c228841bb5ba8/urllib3-2.2.3-py3-none-any.whl (126 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e5/48/1549795ba7742c948d2ad169c1c8cdbae65bc450d6cd753d124b17c8cd32/certifi-2025.8.3-py3-none-any.whl (161 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
# Successfully installed certifi-2025.8.3 charset_normalizer-3.4.3 idna-3.10 requests-2.32.4 urllib3-2.2.3

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting pandas
#   Downloading https://mirrors.aliyun.com/pypi/packages/c3/6c/ea362eef61f05553aaf1a24b3e96b2d0603f5dc71a3bd35688a24ed88843/pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#      ---------------------------------------- 10.8/10.8 MB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading https://mirrors.aliyun.com/pypi/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading https://mirrors.aliyun.com/pypi/packages/5c/23/c7abc0ca0a1526a0774eca151daeb8de62ec457e77262b66b359c3c7679e/tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting numpy>=1.20.3 (from pandas)
#   Downloading https://mirrors.aliyun.com/pypi/packages/69/65/0d47953afa0ad569d12de5f65d964321c208492064c38fe3b0b9744f8d44/numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.24.4 pandas-2.0.3 pytz-2025.2 tzdata-2025.2

# %%
# !pip install matplotlib
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting matplotlib
#   Downloading https://mirrors.aliyun.com/pypi/packages/16/51/58b0b9de42fe1e665736d9286f88b5f1556a0e22bed8a71f468231761083/matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 7.6 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/96/1b/b05cd42c8d21767a0488b883b38658fb9a45f86c293b7b42521a8113dc5d/contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/dc/7a/2b3666e8c13d035adf656a8ae391380656144760353c97f74747c64fd3e5/fonttools-4.57.0-cp38-cp38-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 6.2 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/52/77/7e04cca2ff1dc6ee6b7654cebe233de72b7a3ec5616501b6f3144fb70740/kiwisolver-1.4.7-cp38-cp38-win_amd64.whl (55 kB)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f2/75/3cb820b2812405fc7feb3d0deb701ef0c3de93dc02597115e00704591bc9/pillow-10.4.0-cp38-cp38-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 8.2 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e5/0c/0e3c05b1c87bb6a1c76d281b0f35e78d2d80ac91b5f8f524cebf77f51049/pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.7.5 pillow-10.4.0 pyparsing-3.1.4

# %%
# !pip install opencv-contrib-python==4.6.0.66
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting opencv-contrib-python==4.6.0.66
#   Downloading https://mirrors.aliyun.com/pypi/packages/63/0b/6ef1acbaa21e5245c85a42f9f0ecfaf2e7420b24615a00f0eee170328e6b/opencv_contrib_python-4.6.0.66-cp36-abi3-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from opencv-contrib-python==4.6.0.66) (1.24.4)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.6.0.66

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting scikit-learn
#   Downloading https://mirrors.aliyun.com/pypi/packages/52/2d/ad6928a578c78bb0e44e34a5a922818b14c56716b81d145924f1f291416f/scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\admin\anaconda3\envs\mycv\lib\site-packages (from scikit-learn) (1.24.4)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Downloading https://mirrors.aliyun.com/pypi/packages/32/8e/7f403535ddf826348c9b8417791e28712019962f7e90ff845896d6325d09/scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#      ---------------------------------------- 42.2/42.2 MB 7.9 MB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading https://mirrors.aliyun.com/pypi/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading https://mirrors.aliyun.com/pypi/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.5.0

# %%
# !pip list
# Out:
# Package               Version
# --------------------- -----------
# asttokens             2.0.5
# backcall              0.2.0
# certifi               2025.8.3
# charset-normalizer    3.4.3
# colorama              0.4.6
# comm                  0.2.1
# contourpy             1.1.1
# cycler                0.12.1
# debugpy               1.6.7
# decorator             5.1.1
# executing             0.8.3
# fonttools             4.57.0
# idna                  3.10
# importlib-metadata    7.0.1
# importlib_resources   6.4.5
# ipykernel             6.29.5
# ipython               8.10.0
# jedi                  0.19.1
# joblib                1.4.2
# jupyter_client        8.6.0
# jupyter_core          5.7.2
# kiwisolver            1.4.7
# matplotlib            3.7.5
# matplotlib-inline     0.1.6
# nest-asyncio          1.6.0
# numpy                 1.24.4
# opencv-contrib-python 4.6.0.66
# packaging             24.1
# pandas                2.0.3
# parso                 0.8.3
# pickleshare           0.7.5
# pillow                10.4.0
# pip                   24.2
# platformdirs          3.10.0
# prompt-toolkit        3.0.43
# psutil                5.9.0
# pure-eval             0.2.2
# Pygments              2.15.1
# pyparsing             3.1.4
# python-dateutil       2.9.0.post0
# pytz                  2025.2
# pywin32               305.1
# pyzmq                 25.1.2
# requests              2.32.4
# scikit-learn          1.3.2
# scipy                 1.10.1
# setuptools            75.1.0
# six                   1.16.0
# stack-data            0.2.0
# threadpoolctl         3.5.0
# tornado               6.4.1
# traitlets             5.14.3
# tzdata                2025.2
# urllib3               2.2.3
# wcwidth               0.2.5
# wheel                 0.44.0
# zipp                  3.20.2
